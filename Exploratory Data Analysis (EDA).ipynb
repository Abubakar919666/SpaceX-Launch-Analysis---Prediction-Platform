# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("processed_spacex_data.csv")  # or your merged DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rocket_encoded     186 non-null    int64
#  1   launchpad_encoded  186 non-null    int64
#  2   temperature        186 non-null    float64
#  3   humidity           186 non-null    int64
#  4   wind_speed         186 non-null    float64
#  5   year               186 non-null    int64
#  6   month              186 non-null    int64
#  7   day                186 non-null    int64
#  8   hour               186 non-null    int64
#  9   success            186 non-null    bool
# dtypes: bool(1), float64(2), int64(7)
# memory usage: 13.4 KB

# %%
df.describe()
# Out:
#        rocket_encoded  launchpad_encoded  temperature    humidity  wind_speed  \
# count      186.000000         186.000000   186.000000  186.000000  186.000000
# mean         0.989247           0.817204    25.259516   37.274194    5.829946
# std          0.207670           0.952337    10.717058   24.296704    2.134613
# min          0.000000           0.000000    -8.580000    3.000000    0.630000
# 25%          1.000000           0.000000    22.850000   17.000000    4.120000
# 50%          1.000000           0.000000    27.605000   27.500000    5.860000
# 75%          1.000000           2.000000    32.375000   57.000000    7.230000
# max          2.000000           3.000000    39.880000  100.000000   10.580000
#
#               year       month         day        hour
# count   186.000000  186.000000  186.000000  186.000000
# mean   2018.827957    6.188172   14.919355   12.634409
# std       3.280157    3.363086    8.784443    7.299441
# min    2006.000000    1.000000    1.000000    0.000000
# 25%    2017.000000    3.000000    7.000000    5.250000
# 50%    2020.000000    6.000000   15.000000   14.000000
# 75%    2021.000000    9.000000   22.000000   19.000000
# max    2022.000000   12.000000   31.000000   23.000000

# %% [markdown]
# ## Target Distribution

# %%
sns.countplot(x='success', data=df)
plt.title("Launch Success Distribution")
plt.xlabel("Success (1 = Yes, 0 = No)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Weather Impact on Launch Success

# %%
#  Temperature
sns.boxplot(x='success', y='temperature', data=df)
plt.title("Temperature vs Launch Success")
plt.show()

# %%
# humidity
sns.boxplot(x='success', y='humidity', data=df)
plt.title("Humidity vs Launch Success")
plt.show()

# %%
# wind_speed
sns.boxplot(x='success', y='wind_speed', data=df)
plt.title("Wind Speed vs Launch Success")
plt.show()

# %% [markdown]
# ## Time Influence (Year, Month, Hour)

# %%
# Yearly Launch Trends
plt.figure(figsize=(10, 6))
sns.countplot(x='year', hue='success', data=df)
plt.title("Launch Success by Year")
plt.show()

# %%
# Monthly Distribution
sns.countplot(x='month', hue='success', data=df)
plt.title("Launch Success by Month")
plt.show()

# %%
# Hour of Day
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='hour', hue='success', bins=24, multiple='stack')
plt.title("Launch Success by Hour of Day")
plt.show()

# %% [markdown]
# ## Rocket and Launchpad Effect

# %%
# Rocket Encoded
sns.countplot(x='rocket_encoded', hue='success', data=df)
plt.title("Success by Rocket (Encoded)")
plt.show()

# %%
# Launchpad Encoded
sns.countplot(x='launchpad_encoded', hue='success', data=df)
plt.title("Success by Launchpad (Encoded)")
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
